# %% [markdown]
# # 📊 Brazilian E-Commerce (Olist) Data Engineering & Analytics Project
#
# ## Project Overview
#
# This project performs end-to-end data preprocessing, feature engineering, exploratory data analysis (EDA), and business analytics using the Brazilian E-Commerce (Olist) dataset.
#
# ### Objectives
#
# - Data Understanding
# - Data Cleaning
# - Data Integration
# - Feature Engineering
# - Exploratory Data Analysis
# - Data Quality Report
# - Interactive Flask Dashboard

# %% [markdown]
# # Import Required Libraries

# %%
pip install pandas numpy matplotlib seaborn jupyter
# Out:
# Requirement already satisfied: pandas in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (3.0.3)
# Requirement already satisfied: numpy in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (2.5.1)
# Requirement already satisfied: matplotlib in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (3.11.0)
# Requirement already satisfied: seaborn in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: jupyter in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (1.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: notebook in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyter) (7.6.0)
# Requirement already satisfied: jupyter-console in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyter) (7.17.1)
# Requirement already satisfied: ipykernel in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyter) (7.3.0)
# Requirement already satisfied: ipywidgets in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyter) (8.1.8)
# Requirement already satisfied: jupyterlab in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyter) (4.6.1)
# Requirement already satisfied: six>=1.5 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: comm>=0.1.1 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (1.8.21)
# Requirement already satisfied: ipython>=7.23.1 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (9.15.0)
# Requirement already satisfied: jupyter-client>=8.9.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (8.9.1)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: nest-asyncio2>=1.7.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (1.7.2)
# Requirement already satisfied: psutil>=5.7 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (6.5.7)
# Requirement already satisfied: traitlets>=5.4.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (5.15.1)
# Requirement already satisfied: decorator>=5.1.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.20.0)
# Requirement already satisfied: pexpect>4.6 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: wcwidth in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter) (0.8.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel->jupyter) (0.8.7)
# Requirement already satisfied: typing-extensions>=4.13.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyter-client>=8.9.0->ipykernel->jupyter) (4.16.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->jupyter) (4.10.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from pexpect>4.6->ipython>=7.23.1->ipykernel->jupyter) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter) (3.0.1)
# Requirement already satisfied: pure-eval in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from ipywidgets->jupyter) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from ipywidgets->jupyter) (3.0.16)
# Requirement already satisfied: async-lru>=1.0.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-builder>=1.0.2 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter) (1.0.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.19.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter) (2.20.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: anyio in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (4.14.1)
# Requirement already satisfied: certifi in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.18)
# Requirement already satisfied: h11>=0.16 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (0.25.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.15.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (4.26.0)
# Requirement already satisfied: requests>=2.31 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.34.2)
# Requirement already satisfied: argon2-cffi-bindings in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jinja2>=3.0.3->jupyterlab->jupyter) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2026.6.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (4.1.0)
# Requirement already satisfied: pyyaml>=5.3 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (1.1.0)
# Requirement already satisfied: uri-template in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (4.15.0)
# Requirement already satisfied: bleach!=5.0.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.4.0)
# Requirement already satisfied: defusedxml in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (3.3.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (0.11.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2>=1.1.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (2.21.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.7.0)
# Requirement already satisfied: lark>=1.2.2 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (2.1.0)
# Requirement already satisfied: pycparser in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.8.4)
# Requirement already satisfied: arrow>=0.15.0 in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (1.4.0)
# Requirement already satisfied: tzdata in /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (2026.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sys

print(sys.executable)
# Out:
# /home/aximsoft/PycharmProjects/Britilian_ECommerce/.venv/bin/python

# %%
import os

print(os.getcwd())
os.listdir()
# Out:
# /home/aximsoft/PycharmProjects/Britilian_ECommerce/notebooks
# ['.ipynb_checkpoints', 'olist.ipynb']

# %% [markdown]
# # Load Datasets

# %%
customers = pd.read_csv('../datasets/olist_customers_dataset.csv')
orders = pd.read_csv("../datasets/olist_orders_dataset.csv")
order_items = pd.read_csv("../datasets/olist_order_items_dataset.csv")
products = pd.read_csv("../datasets/olist_products_dataset.csv")
payments = pd.read_csv("../datasets/olist_order_payments_dataset.csv")
reviews = pd.read_csv("../datasets/olist_order_reviews_dataset.csv")
sellers = pd.read_csv("../datasets/olist_sellers_dataset.csv")
geolocation = pd.read_csv("../datasets/olist_geolocation_dataset.csv")
category_translation = pd.read_csv("../datasets/product_category_name_translation.csv")

# %% [markdown]
# # Phase 1 – Data Understanding

# %% [markdown]
# ## Customers Dataset

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  str
#  1   customer_unique_id        99441 non-null  str
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  str
#  4   customer_state            99441 non-null  str
# dtypes: int64(1), str(4)
# memory usage: 3.8 MB

# %%
customers.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %%
customers.shape
# Out:
# (99441, 5)

# %%
customers.dtypes
# Out:
# customer_id                   str
# customer_unique_id            str
# customer_zip_code_prefix    int64
# customer_city                 str
# customer_state                str
# dtype: object

# %%
customers.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
customers.isnull().sum()/len(customers)*100
# Out:
# customer_id                 0.0
# customer_unique_id          0.0
# customer_zip_code_prefix    0.0
# customer_city               0.0
# customer_state              0.0
# dtype: float64

# %%
plt.figure(figsize=(10,5))

sns.heatmap(customers.isnull(),
            cmap="viridis",
            cbar=True)

plt.title("Missing Value Heatmap")
plt.show()

# %% [markdown]
# ### Observation
#
# - Dataset contains customer information.
# - No duplicate records.
# - No missing values.
# - Customer city and state are categorical variables.

# %% [markdown]
# ## Orders Dataset

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  str
#  1   customer_id                    99441 non-null  str
#  2   order_status                   99441 non-null  str
#  3   order_purchase_timestamp       99441 non-null  str
#  4   order_approved_at              99281 non-null  str
#  5   order_delivered_carrier_date   97658 non-null  str
#  6   order_delivered_customer_date  96476 non-null  str
#  7   order_estimated_delivery_date  99441 non-null  str
# dtypes: str(8)
# memory usage: 6.1 MB

# %%
orders.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-03-31 15:08:21  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# top             2018-05-09 15:48:00           2018-05-14 20:02:44
# freq                             47                             3
#
#        order_estimated_delivery_date
# count                          99441
# unique                           459
# top              2017-12-20 00:00:00
# freq                             522

# %%
orders.shape
# Out:
# (99441, 8)

# %%
orders.dtypes
# Out:
# order_id                         str
# customer_id                      str
# order_status                     str
# order_purchase_timestamp         str
# order_approved_at                str
# order_delivered_carrier_date     str
# order_delivered_customer_date    str
# order_estimated_delivery_date    str
# dtype: object

# %%
orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
orders.isnull().sum()/len(orders)*100
# Out:
# order_id                         0.000000
# customer_id                      0.000000
# order_status                     0.000000
# order_purchase_timestamp         0.000000
# order_approved_at                0.160899
# order_delivered_carrier_date     1.793023
# order_delivered_customer_date    2.981668
# order_estimated_delivery_date    0.000000
# dtype: float64

# %%
plt.figure(figsize=(10,5))

sns.heatmap(orders.isnull(),
            cmap="viridis",
            cbar=True)

plt.title("Missing Value Heatmap")
plt.show()

# %% [markdown]
# ## Order Items Dataset

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %%
order_items.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  str
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  str
#  3   seller_id            112650 non-null  str
#  4   shipping_limit_date  112650 non-null  str
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), str(4)
# memory usage: 6.0 MB

# %%
orders.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-03-31 15:08:21  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# top             2018-05-09 15:48:00           2018-05-14 20:02:44
# freq                             47                             3
#
#        order_estimated_delivery_date
# count                          99441
# unique                           459
# top              2017-12-20 00:00:00
# freq                             522

# %%
order_items.shape
# Out:
# (112650, 7)

# %%
order_items.dtypes
# Out:
# order_id                   str
# order_item_id            int64
# product_id                 str
# seller_id                  str
# shipping_limit_date        str
# price                  float64
# freight_value          float64
# dtype: object

# %%
order_items.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
order_items.isnull().sum()/len(order_items)*100
# Out:
# order_id               0.0
# order_item_id          0.0
# product_id             0.0
# seller_id              0.0
# shipping_limit_date    0.0
# price                  0.0
# freight_value          0.0
# dtype: float64

# %%
plt.figure(figsize=(10,5))

sns.heatmap(order_items.isnull(),
            cmap="viridis",
            cbar=True)

plt.title("Missing Value Heatmap")
plt.show()

# %% [markdown]
# ## Products Dataset

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
products.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  str
#  1   product_category_name       32341 non-null  str
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), str(2)
# memory usage: 2.3 MB

# %%
products.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# min            0.000000           7.000000           2.000000
# 25%          300.000000          18.000000           8.000000
# 50%          700.000000          25.000000          13.000000
# 75%         1900.000000          38.000000          21.000000
# max        40425.000000         105.000000         105.000000
#
#        product_width_cm
# count      32949.000000
# mean          23.196728
# std           12.079047
# min            6.000000
# 25%           15.000000
# 50%           20.000000
# 75%           30.000000
# max          118.000000

# %%
products.shape
# Out:
# (32951, 9)

# %%
products.dtypes
# Out:
# product_id                        str
# product_category_name             str
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object

# %%
products.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
products.isnull().sum()/len(products)*100
# Out:
# product_id                    0.000000
# product_category_name         1.851234
# product_name_lenght           1.851234
# product_description_lenght    1.851234
# product_photos_qty            1.851234
# product_weight_g              0.006070
# product_length_cm             0.006070
# product_height_cm             0.006070
# product_width_cm              0.006070
# dtype: float64

# %%
plt.figure(figsize=(10,5))

sns.heatmap(products.isnull(),
            cmap="viridis",
            cbar=True)

plt.title("Missing Value Heatmap")
plt.show()

# %% [markdown]
# ##payments dataset

# %%
payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
payments.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  str
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  str
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), str(2)
# memory usage: 4.0 MB

# %%
payments.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %%
payments.shape
# Out:
# (103886, 5)

# %%
payments.dtypes
# Out:
# order_id                    str
# payment_sequential        int64
# payment_type                str
# payment_installments      int64
# payment_value           float64
# dtype: object

# %%
payments.isnull().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
payments.isnull().sum()/len(payments)*100
# Out:
# order_id                0.0
# payment_sequential      0.0
# payment_type            0.0
# payment_installments    0.0
# payment_value           0.0
# dtype: float64

# %%
plt.figure(figsize=(10,5))

sns.heatmap(payments.isnull(),
            cmap="viridis",
            cbar=True)

plt.title("Missing Value Heatmap")
plt.show()

# %% [markdown]
# ##Sellers Dataset

# %%
sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
sellers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   str
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   str
#  3   seller_state            3095 non-null   str
# dtypes: int64(1), str(3)
# memory usage: 96.8 KB

# %%
sellers.describe()
# Out:
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %%
sellers.shape
# Out:
# (3095, 4)

# %%
sellers.dtypes
# Out:
# seller_id                   str
# seller_zip_code_prefix    int64
# seller_city                 str
# seller_state                str
# dtype: object

# %%
sellers.isnull().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
sellers.isnull().sum()/len(sellers)*100
# Out:
# seller_id                 0.0
# seller_zip_code_prefix    0.0
# seller_city               0.0
# seller_state              0.0
# dtype: float64

# %%
plt.figure(figsize=(10,5))

sns.heatmap(sellers.isnull(),
            cmap="viridis",
            cbar=True)

plt.title("Missing Value Heatmap")
plt.show()

# %% [markdown]
# ##reviews dataset

# %%
reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %%
reviews.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  str
#  1   order_id                 99224 non-null  str
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  str
#  4   review_comment_message   40977 non-null  str
#  5   review_creation_date     99224 non-null  str
#  6   review_answer_timestamp  99224 non-null  str
# dtypes: int64(1), str(6)
# memory usage: 5.3 MB

# %%
reviews.describe()
# Out:
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
reviews.shape
# Out:
# (99224, 7)

# %%
reviews.dtypes
# Out:
# review_id                    str
# order_id                     str
# review_score               int64
# review_comment_title         str
# review_comment_message       str
# review_creation_date         str
# review_answer_timestamp      str
# dtype: object

# %%
reviews.isnull().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
reviews.isnull().sum()/len(reviews)*100
# Out:
# review_id                   0.000000
# order_id                    0.000000
# review_score                0.000000
# review_comment_title       88.341530
# review_comment_message     58.702532
# review_creation_date        0.000000
# review_answer_timestamp     0.000000
# dtype: float64

# %%
plt.figure(figsize=(10,5))

sns.heatmap(reviews.isnull(),
            cmap="viridis",
            cbar=True)

plt.title("Missing Value Heatmap")
plt.show()

# %% [markdown]
# #geolocation dataset

# %%
geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
geolocation.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  str
#  4   geolocation_state            1000163 non-null  str
# dtypes: float64(2), int64(1), str(2)
# memory usage: 38.2 MB

# %%
geolocation.describe()
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %%
geolocation.shape
# Out:
# (1000163, 5)

# %%
geolocation.dtypes
# Out:
# geolocation_zip_code_prefix      int64
# geolocation_lat                float64
# geolocation_lng                float64
# geolocation_city                   str
# geolocation_state                  str
# dtype: object

# %%
geolocation.isnull().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
geolocation.isnull().sum()/len(geolocation)*100
# Out:
# geolocation_zip_code_prefix    0.0
# geolocation_lat                0.0
# geolocation_lng                0.0
# geolocation_city               0.0
# geolocation_state              0.0
# dtype: float64

# %%
plt.figure(figsize=(10,5))

sns.heatmap(geolocation.isnull(),
            cmap="viridis",
            cbar=True)

plt.title("Missing Value Heatmap")
plt.show()

# %% [markdown]
# ##category translation dataset

# %%
category_translation.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
category_translation.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     str
#  1   product_category_name_english  71 non-null     str
# dtypes: str(2)
# memory usage: 1.2 KB

# %%
category_translation.describe()
# Out:
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %%
category_translation.shape
# Out:
# (71, 2)

# %%
category_translation.dtypes
# Out:
# product_category_name            str
# product_category_name_english    str
# dtype: object

# %%
category_translation.isnull().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
category_translation.isnull().sum()/len(category_translation)*100
# Out:
# product_category_name            0.0
# product_category_name_english    0.0
# dtype: float64

# %%
plt.figure(figsize=(10,5))

sns.heatmap(category_translation.isnull(),
            cmap="viridis",
            cbar=True)

plt.title("Missing Value Heatmap")
plt.show()

# %% [markdown]
# # Phase 2 – Data Cleaning
#
# In this phase, each dataset is cleaned individually before merging.
#
# The following preprocessing steps are performed:
#
# - Remove leading and trailing spaces
# - Handle missing values
# - Remove duplicate records
# - Convert data types
# - Detect invalid values
# - Detect and handle outliers

# %% [markdown]
# ## Customers Dataset Cleaning

# %%
customers.columns = customers.columns.str.strip()

customers["customer_city"] = (
    customers["customer_city"]
    .str.strip()
)

# %%
customers.isnull().sum()

customers.isnull().mean()*100
# Out:
# customer_id                 0.0
# customer_unique_id          0.0
# customer_zip_code_prefix    0.0
# customer_city               0.0
# customer_state              0.0
# dtype: float64

# %%
customers.duplicated().sum()

customers.drop_duplicates(inplace=True)

customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers.dtypes
# Out:
# customer_id                   str
# customer_unique_id            str
# customer_zip_code_prefix    int64
# customer_city                 str
# customer_state                str
# dtype: object

# %%
customers["customer_zip_code_prefix"] = (
    customers["customer_zip_code_prefix"].astype(str)
)

# %%
customers.dtypes
# Out:
# customer_id                 str
# customer_unique_id          str
# customer_zip_code_prefix    str
# customer_city               str
# customer_state              str
# dtype: object

# %% [markdown]
# ### Observation
#
# No significant outliers were detected in the Customers dataset.

# %%
customers.to_csv(
    "../cleaned/customers_clean.csv",
    index=False
)

# %% [markdown]
# ## Orders Dataset Cleaning

# %%
orders.columns = orders.columns.str.strip()

# %%
text_columns = orders.select_dtypes(include="str").columns

for col in text_columns:
    orders[col] = orders[col].str.strip()

# %%
orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
orders.isnull().mean()*100
# Out:
# order_id                         0.000000
# customer_id                      0.000000
# order_status                     0.000000
# order_purchase_timestamp         0.000000
# order_approved_at                0.160899
# order_delivered_carrier_date     1.793023
# order_delivered_customer_date    2.981668
# order_estimated_delivery_date    0.000000
# dtype: float64

# %%
orders.duplicated().sum()
# Out:
# np.int64(0)

# %%
orders.drop_duplicates(inplace=True)

# %%
orders.duplicated().sum()
# Out:
# np.int64(0)

# %%
orders["order_purchase_timestamp"] = pd.to_datetime(
    orders["order_purchase_timestamp"]
)

orders["order_approved_at"] = pd.to_datetime(
    orders["order_approved_at"]
)

orders["order_delivered_carrier_date"] = pd.to_datetime(
    orders["order_delivered_carrier_date"]
)

orders["order_delivered_customer_date"] = pd.to_datetime(
    orders["order_delivered_customer_date"]
)

orders["order_estimated_delivery_date"] = pd.to_datetime(
    orders["order_estimated_delivery_date"]
)

# %%
orders.dtypes
# Out:
# order_id                                    str
# customer_id                                 str
# order_status                                str
# order_purchase_timestamp         datetime64[us]
# order_approved_at                datetime64[us]
# order_delivered_carrier_date     datetime64[us]
# order_delivered_customer_date    datetime64[us]
# order_estimated_delivery_date    datetime64[us]
# dtype: object

# %%
(
orders["order_approved_at"]
>=
orders["order_purchase_timestamp"]
).sum()
# Out:
# np.int64(99281)

# %%
(
orders["order_delivered_carrier_date"]
<
orders["order_approved_at"]
).sum()
# Out:
# np.int64(1359)

# %%
(
orders["order_delivered_customer_date"]
<
orders["order_delivered_carrier_date"]
).sum()
# Out:
# np.int64(23)

# %%
missing = (
    orders.isnull().mean()*100
)

missing = missing[missing > 0]

plt.figure(figsize=(10,5))

missing.sort_values().plot(kind="barh")

plt.title("Missing Value Percentage")
plt.xlabel("Percentage")

plt.show()

# %%
orders.loc[
    orders["order_delivered_carrier_date"] < orders["order_approved_at"],
    [
        "order_id",
        "order_purchase_timestamp",
        "order_approved_at",
        "order_delivered_carrier_date"
    ]
].head(10)
# Out:
#                              order_id order_purchase_timestamp  \
# 15   dcb36b511fcac050b97cd5c05de84dc3      2018-06-07 19:03:12
# 64   688052146432ef8253587b930b01a06d      2018-04-22 08:48:13
# 199  58d4c4747ee059eeeb865b349b41f53a      2018-07-21 12:49:32
# 210  412fccb2b44a99b36714bca3fef8ad7b      2018-07-22 22:30:05
# 415  56a4ac10a4a8f2ba7693523bb439eede      2018-07-22 13:04:47
# 481  32e4fa9bb468884309b58b9348de70c3      2018-07-04 16:49:21
# 483  4df92d82d79c3b52c7138679fa9b07fc      2018-07-24 11:32:11
# 585  16e38caa92e342c7780f68832f832d4d      2018-05-07 01:09:09
# 615  b9afddbdcfadc9a87b41a83271c3e888      2018-08-16 13:50:48
# 817  6051e6d3da9a50b7325cbe9c81025062      2018-07-03 23:40:16
#
#       order_approved_at order_delivered_carrier_date
# 15  2018-06-12 23:31:02          2018-06-11 14:54:00
# 64  2018-04-24 18:25:22          2018-04-23 19:19:14
# 199 2018-07-26 23:31:53          2018-07-24 12:57:00
# 210 2018-07-23 12:31:53          2018-07-23 12:24:00
# 415 2018-07-27 23:31:09          2018-07-24 14:03:00
# 481 2018-07-05 16:33:06          2018-07-05 14:50:00
# 483 2018-07-29 23:30:52          2018-07-26 14:46:00
# 585 2018-05-07 16:52:39          2018-05-07 15:09:00
# 615 2018-08-16 14:05:13          2018-08-16 13:27:00
# 817 2018-07-05 16:31:26          2018-07-04 12:14:00

# %%
orders["order_status"].unique()
# Out:
# <StringArray>
# [  'delivered',    'invoiced',     'shipped',  'processing', 'unavailable',
#     'canceled',     'created',    'approved']
# Length: 8, dtype: str

# %%
orders.loc[
    orders["order_delivered_customer_date"] < orders["order_delivered_carrier_date"],
    [
        "order_id",
        "order_delivered_carrier_date",
        "order_delivered_customer_date"
    ]
].head()
# Out:
#                                order_id order_delivered_carrier_date  \
# 6437   a1abeb653a4d4cd1e142ccb8c82cd069          2017-07-28 16:57:58
# 9553   383aa8b2724fe452d9ccd9934a8c628b          2017-07-07 17:22:41
# 13487  cb1134f9010d242e9515ad1c78ec0c39          2017-07-20 19:22:02
# 14474  dceb62e8fa94b46006c9554fed743df0          2017-08-01 18:23:30
# 19268  5f9d46795c3126674e52becb3a1a517f          2017-07-20 23:03:42
#
#       order_delivered_customer_date
# 6437            2017-07-25 19:32:56
# 9553            2017-07-06 14:27:51
# 13487           2017-07-19 14:13:28
# 14474           2017-07-26 18:09:10
# 19268           2017-07-20 18:52:41

# %%
orders.to_csv("../cleaned/orders_clean.csv", index=False)

# %% [markdown]
# ### Observation
#
# No numerical columns requiring outlier treatment were identified.

# %% [markdown]
# ## Order Items Dataset Cleaning

# %%
order_items = pd.read_csv("../datasets/olist_order_items_dataset.csv")

# %%
# Remove leading/trailing spaces
order_items.columns = order_items.columns.str.strip()

# %%
text_columns = order_items.select_dtypes(include="str").columns

for col in text_columns:
    order_items[col] = order_items[col].str.strip()

# %%
order_items.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
order_items.isnull().mean()*100
# Out:
# order_id               0.0
# order_item_id          0.0
# product_id             0.0
# seller_id              0.0
# shipping_limit_date    0.0
# price                  0.0
# freight_value          0.0
# dtype: float64

# %%
before_duplicates = order_items.duplicated().sum()

order_items.drop_duplicates(inplace=True)

after_duplicates = order_items.duplicated().sum()

print("Duplicates Removed:", before_duplicates - after_duplicates)
# Out:
# Duplicates Removed: 0

# %%
order_items.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  str
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  str
#  3   seller_id            112650 non-null  str
#  4   shipping_limit_date  112650 non-null  str
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), str(4)
# memory usage: 6.0 MB

# %%
order_items.dtypes
# Out:
# order_id                   str
# order_item_id            int64
# product_id                 str
# seller_id                  str
# shipping_limit_date        str
# price                  float64
# freight_value          float64
# dtype: object

# %%
order_items["shipping_limit_date"] = pd.to_datetime(
    order_items["shipping_limit_date"]
)

# %%
order_items.dtypes
# Out:
# order_id                          str
# order_item_id                   int64
# product_id                        str
# seller_id                         str
# shipping_limit_date    datetime64[us]
# price                         float64
# freight_value                 float64
# dtype: object

# %% [markdown]
# ### Invalid Value Validation

# %%
print("Invalid Price Values :", (order_items["price"] < 0).sum())
# Out:
# Invalid Price Values : 0

# %%
print("Invalid Freight Values :", (order_items["freight_value"] < 0).sum())
# Out:
# Invalid Freight Values : 0

# %% [markdown]
# ### Outlier Detection - Price

# %%
price_before = order_items["price"].copy()

# %%
plt.figure(figsize=(8,4))

sns.boxplot(x=order_items["price"])

plt.title("Price Before Outlier Removal")

plt.show()

# %%
Q1 = order_items["price"].quantile(0.25)
Q3 = order_items["price"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

price_outliers = order_items[
    (order_items["price"] < lower) |
    (order_items["price"] > upper)
]

print("Price Outliers:", len(price_outliers))
# Out:
# Price Outliers: 8427

# %% [markdown]
# ### Outlier Detection - Freight Value

# %%
freight_before = order_items["freight_value"].copy()

# %%
plt.figure(figsize=(8,4))

sns.boxplot(x=order_items["freight_value"])

plt.title("Freight Value Before Outlier Removal")

plt.show()

# %%
Q1 = order_items["freight_value"].quantile(0.25)
Q3 = order_items["freight_value"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

freight_outliers = order_items[
    (order_items["freight_value"] < lower) |
    (order_items["freight_value"] > upper)
]

print("Freight Outliers:", len(freight_outliers))
# Out:
# Freight Outliers: 12134

# %%
order_items.to_csv(
    "../cleaned/order_items_clean.csv",
    index=False
)

# %% [markdown]
# ## Products Dataset Cleaning

# %%
products = pd.read_csv("../datasets/olist_products_dataset.csv")

# %%
products.columns = products.columns.str.strip()

# %%
text_columns = products.select_dtypes(include="str").columns

for col in text_columns:
    products[col] = products[col].str.strip()

# %%
print("Missing Values")

products.isnull().sum()
# Out:
# Missing Values
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
missing_percentage = (
    products.isnull().mean() * 100
).round(2)

missing_percentage
# Out:
# product_id                    0.00
# product_category_name         1.85
# product_name_lenght           1.85
# product_description_lenght    1.85
# product_photos_qty            1.85
# product_weight_g              0.01
# product_length_cm             0.01
# product_height_cm             0.01
# product_width_cm              0.01
# dtype: float64

# %%
print("Duplicates Before :", products.duplicated().sum())

products.drop_duplicates(inplace=True)

print("Duplicates After :", products.duplicated().sum())
# Out:
# Duplicates Before : 0
# Duplicates After : 0

# %%
products.dtypes
# Out:
# product_id                        str
# product_category_name             str
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object

# %%
products.rename(
    columns={
        "product_name_lenght": "product_name_length",
        "product_description_lenght": "product_description_length"
    },
    inplace=True
)

# %%
products.columns
# Out:
# Index(['product_id', 'product_category_name', 'product_name_length',
#        'product_description_length', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm'],
#       dtype='str')

# %% [markdown]
# ### Observation
#
# The Products dataset contains appropriate data types. No datatype conversion was required.

# %%
print("Invalid Product Weight :",
      (products["product_weight_g"] < 0).sum())

print("Invalid Product Length :",
      (products["product_length_cm"] < 0).sum())

print("Invalid Product Height :",
      (products["product_height_cm"] < 0).sum())

print("Invalid Product Width :",
      (products["product_width_cm"] < 0).sum())
# Out:
# Invalid Product Weight : 0
# Invalid Product Length : 0
# Invalid Product Height : 0
# Invalid Product Width : 0

# %% [markdown]
# ##product outliers detection

# %%
weight_before = products["product_weight_g"].copy()

# %%
plt.figure(figsize=(8,4))

sns.boxplot(
    x=products["product_weight_g"]
)

plt.title("Product Weight Before Outlier Removal")

plt.show()

# %%
Q1 = products["product_weight_g"].quantile(0.25)

Q3 = products["product_weight_g"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - (1.5 * IQR)

upper = Q3 + (1.5 * IQR)

# %%
outliers_weight = products[
    (products["product_weight_g"] < lower) |
    (products["product_weight_g"] > upper)
]

print("Weight Outliers :", len(outliers_weight))
# Out:
# Weight Outliers : 4551

# %%
length_before = products["product_length_cm"].copy()

# %%
plt.figure(figsize=(8,4))

sns.boxplot(
    x=products["product_length_cm"]
)

plt.title("Product length Before Outlier Removal")

plt.show()

# %%
Q1 = products["product_length_cm"].quantile(0.25)

Q3 = products["product_length_cm"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - (1.5 * IQR)

upper = Q3 + (1.5 * IQR)

# %%
outliers_length = products[
    (products["product_length_cm"] < lower) |
    (products["product_length_cm"] > upper)
]

print("Length Outliers :", len(outliers_weight))
# Out:
# Length Outliers : 4551

# %%
height_before = products["product_height_cm"].copy()

# %%
plt.figure(figsize=(8,4))

sns.boxplot(
    x=products["product_height_cm"]
)

plt.title("Product height Before Outlier Removal")

plt.show()

# %%
Q1 = products["product_height_cm"].quantile(0.25)

Q3 = products["product_height_cm"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - (1.5 * IQR)

upper = Q3 + (1.5 * IQR)

# %%
outliers_height = products[
    (products["product_height_cm"] < lower) |
    (products["product_height_cm"] > upper)
]

print("Height Outliers :", len(outliers_weight))
# Out:
# Height Outliers : 4551

# %%
width_before = products["product_width_cm"].copy()

# %%
plt.figure(figsize=(8,4))

sns.boxplot(
    x=products["product_width_cm"]
)

plt.title("Product width Before Outlier Removal")

plt.show()

# %%
Q1 = products["product_width_cm"].quantile(0.25)

Q3 = products["product_width_cm"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - (1.5 * IQR)

upper = Q3 + (1.5 * IQR)

# %%
outliers_width = products[
    (products["product_width_cm"] < lower) |
    (products["product_width_cm"] > upper)
]

print("Width Outliers :", len(outliers_weight))
# Out:
# Width Outliers : 4551

# %%
products.to_csv(
    "../cleaned/products_clean.csv",
    index=False
)

# %% [markdown]
# ### Products Cleaning Summary
#
# ✔ Removed leading and trailing spaces
#
# ✔ Checked missing values
#
# ✔ Removed duplicate records
#
# ✔ Corrected column name spelling mistakes
#
# ✔ Validated invalid values
#
# ✔ Detected and removed outliers using the IQR method
#
# ✔ Exported the cleaned dataset

# %% [markdown]
# ## Sellers Dataset Cleaning

# %%
# Remove spaces from column names
sellers.columns = sellers.columns.str.strip()

# Remove spaces from string columns
text_columns = sellers.select_dtypes(include="str").columns

for col in text_columns:
    sellers[col] = sellers[col].str.strip()

# %%
print("Missing Values")

sellers.isnull().sum()
# Out:
# Missing Values
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
missing_percentage = (
    sellers.isnull().mean() * 100
).round(2)

missing_percentage
# Out:
# seller_id                 0.0
# seller_zip_code_prefix    0.0
# seller_city               0.0
# seller_state              0.0
# dtype: float64

# %%
print("Duplicates Before :", sellers.duplicated().sum())

sellers.drop_duplicates(inplace=True)

print("Duplicates After :", sellers.duplicated().sum())
# Out:
# Duplicates Before : 0
# Duplicates After : 0

# %%
sellers.dtypes
# Out:
# seller_id                   str
# seller_zip_code_prefix    int64
# seller_city                 str
# seller_state                str
# dtype: object

# %%
sellers["seller_zip_code_prefix"] = (
    sellers["seller_zip_code_prefix"]
    .astype(str)
)

# %%
sellers.dtypes
# Out:
# seller_id                 str
# seller_zip_code_prefix    str
# seller_city               str
# seller_state              str
# dtype: object

# %%
print(
    "Missing Seller ZIP Codes :",
    sellers["seller_zip_code_prefix"].eq("").sum()
)
# Out:
# Missing Seller ZIP Codes : 0

# %%
print("Unique Seller States")

sorted(sellers["seller_state"].unique())
# Out:
# Unique Seller States
# ['AC',
#  'AM',
#  'BA',
#  'CE',
#  'DF',
#  'ES',
#  'GO',
#  'MA',
#  'MG',
#  'MS',
#  'MT',
#  'PA',
#  'PB',
#  'PE',
#  'PI',
#  'PR',
#  'RJ',
#  'RN',
#  'RO',
#  'RS',
#  'SC',
#  'SE',
#  'SP']

# %%
print("Number of Seller Cities")

sellers["seller_city"].nunique()
# Out:
# Number of Seller Cities
# 611

# %% [markdown]
# ### Observation
#
# - No missing values were found in the Sellers dataset.
# - Duplicate records were removed if present.
# - ZIP code prefix was converted to string because it represents a location identifier.
# - Seller state and city values were validated successfully.

# %% [markdown]
# ### Outlier Detection
#
# The Sellers dataset does not contain numerical business variables suitable for outlier detection.

# %%
sellers.to_csv(
    "../cleaned/sellers_clean.csv",
    index=False
)

# %% [markdown]
# ### Sellers Cleaning Summary
#
# ✔ Removed leading and trailing spaces
#
# ✔ Checked missing values
#
# ✔ Removed duplicate records
#
# ✔ Converted ZIP code prefix to string
#
# ✔ Validated seller location data
#
# ✔ Exported cleaned dataset

# %%
## Payments Dataset Cleaning

# %%
payments = pd.read_csv("datasets/olist_order_payments_dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[177], line 1
# ----> 1 payments = pd.read_csv("datasets/olist_order_payments_dataset.csv")
#
# File ~/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~/PycharmProjects/Britilian_ECommerce/.venv/lib/python3.12/site-packages/pandas/io/common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datasets/olist_order_payments_dataset.csv'

# %%
# Remove spaces from column names
payments.columns = payments.columns.str.strip()

# Remove spaces from string columns
string_columns = [
    "payment_type"
]

for column in string_columns:
    payments[column] = payments[column].str.strip()

# %%
print("Missing Values")

payments.isnull().sum()
# Out:
# Missing Values
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
missing_percentage = (
    payments.isnull().mean() * 100
).round(2)

missing_percentage
# Out:
# order_id                0.0
# payment_sequential      0.0
# payment_type            0.0
# payment_installments    0.0
# payment_value           0.0
# dtype: float64

# %%
print("Duplicates Before :", payments.duplicated().sum())

payments.drop_duplicates(inplace=True)

print("Duplicates After :", payments.duplicated().sum())
# Out:
# Duplicates Before : 0
# Duplicates After : 0

# %%
payments.dtypes
# Out:
# order_id                    str
# payment_sequential        int64
# payment_type                str
# payment_installments      int64
# payment_value           float64
# dtype: object

# %%
print(
    "Invalid Payment Values :",
    (payments["payment_value"] < 0).sum()
)
# Out:
# Invalid Payment Values : 0

# %%
print(
    "Invalid Installments :",
    (payments["payment_installments"] < 0).sum()
)
# Out:
# Invalid Installments : 0

# %%
payments["payment_type"].value_counts()
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: count, dtype: int64

# %% [markdown]
# ### Observation
#
# - No negative payment values were found.
# - Installment values are valid.
# - Payment methods were verified successfully.

# %%
### Outlier Detection - Payment Value

# %%
payment_before = payments["payment_value"].copy()

# %%
plt.figure(figsize=(8,4))

sns.boxplot(
    x=payments["payment_value"]
)

plt.title("Payment Value Before Outlier Removal")

plt.show()

# %%
Q1 = payments["payment_value"].quantile(0.25)

Q3 = payments["payment_value"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - (1.5 * IQR)

upper = Q3 + (1.5 * IQR)

print("Lower Bound :", lower)
print("Upper Bound :", upper)
# Out:
# Lower Bound : -115.78125000000003
# Upper Bound : 344.40875000000005

# %%
outliers_payment = payments[
    (payments["payment_value"] < lower) |
    (payments["payment_value"] > upper)
]

print("Number of Payment Outliers :", len(outliers_payment))
# Out:
# Number of Payment Outliers : 7981

# %%
payments.to_csv(
    "../cleaned/payments_clean.csv",
    index=False
)

# %% [markdown]
# ### Payments Cleaning Summary
#
# ✔ Removed leading and trailing spaces
#
# ✔ Checked missing values
#
# ✔ Removed duplicate records
#
# ✔ Validated payment values
#
# ✔ Detected and removed outliers using the IQR method
#
# ✔ Exported the cleaned dataset

# %%
## Reviews Dataset Cleaning

# %%
# Remove spaces from column names
reviews.columns = reviews.columns.str.strip()

# Remove spaces from string columns
string_columns = [
    "review_comment_title",
    "review_comment_message"
]

for column in string_columns:
    reviews[column] = reviews[column].str.strip()

# %%
print("Missing Values")

reviews.isnull().sum()
# Out:
# Missing Values
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
missing_percentage = (
    reviews.isnull().mean() * 100
).round(2)

missing_percentage
# Out:
# review_id                   0.00
# order_id                    0.00
# review_score                0.00
# review_comment_title       88.34
# review_comment_message     58.70
# review_creation_date        0.00
# review_answer_timestamp     0.00
# dtype: float64

# %%
reviews["review_comment_title"] = (
    reviews["review_comment_title"]
    .fillna("No Title")
)

reviews["review_comment_message"] = (
    reviews["review_comment_message"]
    .fillna("No Comment")
)

# %%
reviews.isnull().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %%
print("Duplicates Before :", reviews.duplicated().sum())

reviews.drop_duplicates(inplace=True)

print("Duplicates After :", reviews.duplicated().sum())
# Out:
# Duplicates Before : 0
# Duplicates After : 0

# %%
date_columns = [
    "review_creation_date",
    "review_answer_timestamp"
]

for column in date_columns:
    reviews[column] = pd.to_datetime(reviews[column])

# %%
reviews.dtypes
# Out:
# review_id                             str
# order_id                              str
# review_score                        int64
# review_comment_title                  str
# review_comment_message                str
# review_creation_date       datetime64[us]
# review_answer_timestamp    datetime64[us]
# dtype: object

# %%
invalid_reviews = reviews[
    (reviews["review_score"] < 1) |
    (reviews["review_score"] > 5)
]

print("Invalid Review Scores :", len(invalid_reviews))
# Out:
# Invalid Review Scores : 0

# %%
reviews["review_score"].value_counts().sort_index()
# Out:
# review_score
# 1    11424
# 2     3151
# 3     8179
# 4    19142
# 5    57328
# Name: count, dtype: int64

# %% [markdown]
# ### Observation
#
# - Review scores are valid and range from 1 to 5.
# - Missing review comments were replaced with default values.
# - Review dates were converted to datetime format.

# %% [markdown]
# ### Outlier Detection
#
# Outlier detection was **not performed** because:
#
# - `review_score` is an ordinal rating (1–5), not a continuous numerical measurement.
# - Other columns are identifiers, dates, or text fields.
# - Therefore, IQR outlier detection is not appropriate for this dataset.

# %%
reviews.to_csv(
    "../cleaned/reviews_clean.csv",
    index=False
)

# %%
## Geolocation Dataset Cleaning

# %%
# Remove spaces from column names
geolocation.columns = geolocation.columns.str.strip()

# Remove spaces from string columns
string_columns = [
    "geolocation_city",
    "geolocation_state"
]

for column in string_columns:
    geolocation[column] = geolocation[column].str.strip()

# %%
print("Missing Values")

geolocation.isnull().sum()
# Out:
# Missing Values
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
missing_percentage = (
    geolocation.isnull().mean() * 100
).round(2)

missing_percentage
# Out:
# geolocation_zip_code_prefix    0.0
# geolocation_lat                0.0
# geolocation_lng                0.0
# geolocation_city               0.0
# geolocation_state              0.0
# dtype: float64

# %%
print("Duplicates Before :", geolocation.duplicated().sum())
# Out:
# Duplicates Before : 261831

# %%
geolocation.drop_duplicates(inplace=True)

print("Duplicates After :", geolocation.duplicated().sum())
# Out:
# Duplicates After : 0

# %%
geolocation["geolocation_zip_code_prefix"] = (
    geolocation["geolocation_zip_code_prefix"]
    .astype(str)
)

# %%
geolocation.dtypes
# Out:
# geolocation_zip_code_prefix        str
# geolocation_lat                float64
# geolocation_lng                float64
# geolocation_city                   str
# geolocation_state                  str
# dtype: object

# %%
invalid_latitude = geolocation[
    (geolocation["geolocation_lat"] < -90) |
    (geolocation["geolocation_lat"] > 90)
]

print("Invalid Latitude :", len(invalid_latitude))
# Out:
# Invalid Latitude : 0

# %%
invalid_longitude = geolocation[
    (geolocation["geolocation_lng"] < -180) |
    (geolocation["geolocation_lng"] > 180)
]

print("Invalid Longitude :", len(invalid_longitude))
# Out:
# Invalid Longitude : 0

# %%
sorted(geolocation["geolocation_state"].unique())
# Out:
# ['AC',
#  'AL',
#  'AM',
#  'AP',
#  'BA',
#  'CE',
#  'DF',
#  'ES',
#  'GO',
#  'MA',
#  'MG',
#  'MS',
#  'MT',
#  'PA',
#  'PB',
#  'PE',
#  'PI',
#  'PR',
#  'RJ',
#  'RN',
#  'RO',
#  'RR',
#  'RS',
#  'SC',
#  'SE',
#  'SP',
#  'TO']

# %% [markdown]
# ### Observation
#
# - No missing values were found.
# - Duplicate records were successfully removed.
# - ZIP code was converted to string.
# - Latitude and longitude values are within valid geographic ranges.

# %% [markdown]
# ### Outlier Detection
#
# Outlier detection was not performed because latitude and longitude are geographical coordinates, not business measurements. Extreme coordinate values are not considered statistical outliers in this context.

# %%
geolocation.to_csv(
    "../cleaned/geolocation_clean.csv",
    index=False
)

# %% [markdown]
# ### Geolocation Cleaning Summary
#
# ✔ Removed leading and trailing spaces
#
# ✔ Checked missing values
#
# ✔ Removed duplicate records
#
# ✔ Converted ZIP code to string
#
# ✔ Validated latitude and longitude values
#
# ✔ Exported the cleaned dataset

# %% [markdown]
# ## Category Translation Dataset Cleaning

# %%
# Remove spaces from column names
category_translation.columns = category_translation.columns.str.strip()

# Remove spaces from string columns
string_columns = [
    "product_category_name",
    "product_category_name_english"
]

for column in string_columns:
    category_translation[column] = (
        category_translation[column]
        .str.strip()
    )

# %%
print("Missing Values")

category_translation.isnull().sum()
# Out:
# Missing Values
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
missing_percentage = (
    category_translation.isnull().mean() * 100
).round(2)

missing_percentage
# Out:
# product_category_name            0.0
# product_category_name_english    0.0
# dtype: float64

# %%
print("Duplicates Before :", category_translation.duplicated().sum())

category_translation.drop_duplicates(inplace=True)

print("Duplicates After :", category_translation.duplicated().sum())
# Out:
# Duplicates Before : 0
# Duplicates After : 0

# %%
category_translation.dtypes
# Out:
# product_category_name            str
# product_category_name_english    str
# dtype: object

# %%
print(
    "Empty Portuguese Category Names :",
    category_translation["product_category_name"]
    .eq("")
    .sum()
)

print(
    "Empty English Category Names :",
    category_translation["product_category_name_english"]
    .eq("")
    .sum()
)
# Out:
# Empty Portuguese Category Names : 0
# Empty English Category Names : 0

# %%
category_translation[
    "product_category_name_english"
].value_counts().head()
# Out:
# product_category_name_english
# health_beauty            1
# computers_accessories    1
# auto                     1
# bed_bath_table           1
# furniture_decor          1
# Name: count, dtype: int64

# %% [markdown]
# ### Observation
#
# - No missing values were found.
# - Duplicate records were removed if present.
# - Portuguese and English category names were validated successfully.

# %% [markdown]
# ### Outlier Detection
#
# Outlier detection was not performed because this dataset contains only categorical text data.

# %%
category_translation.to_csv(
    "../cleaned/category_translation_clean.csv",
    index=False
)

# %% [markdown]
# ### Category Translation Cleaning Summary
#
# ✔ Removed leading and trailing spaces
#
# ✔ Checked missing values
#
# ✔ Removed duplicate records
#
# ✔ Validated category names
#
# ✔ Exported cleaned dataset

# %%
## Phase 3 – Feature Engineering

# %%
customers = pd.read_csv("../cleaned/customers_clean.csv")
orders = pd.read_csv("../cleaned/orders_clean.csv")
order_items = pd.read_csv("../cleaned/order_items_clean.csv")
products = pd.read_csv("../cleaned/products_clean.csv")
payments = pd.read_csv("../cleaned/payments_clean.csv")
reviews = pd.read_csv("../cleaned/reviews_clean.csv")
sellers = pd.read_csv("../cleaned/sellers_clean.csv")
category_translation = pd.read_csv("../cleaned/category_translation_clean.csv")

# %%
merged_df = orders.merge(
    customers,
    on="customer_id",
    how="left"
)

# %%
merged_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date                customer_unique_id  \
# 0                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 1                    2018-08-13  af07308b275d755c9edb36a90c618231
# 2                    2018-09-04  3a653a41f6f9fc3d2a113cf8398680e8
# 3                    2017-12-15  7c142cf63193a1473d2e66489a9ae977
# 4                    2018-02-26  72632f0f9dd73dfee390c9b22eb56dd6
#
#    customer_zip_code_prefix            customer_city customer_state
# 0                      3149                sao paulo             SP
# 1                     47813                barreiras             BA
# 2                     75265               vianopolis             GO
# 3                     59296  sao goncalo do amarante             RN
# 4                      9195              santo andre             SP

# %%
merged_df.shape
# Out:
# (99441, 12)

# %%
merged_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  str
#  1   customer_id                    99441 non-null  str
#  2   order_status                   99441 non-null  str
#  3   order_purchase_timestamp       99441 non-null  str
#  4   order_approved_at              99281 non-null  str
#  5   order_delivered_carrier_date   97658 non-null  str
#  6   order_delivered_customer_date  96476 non-null  str
#  7   order_estimated_delivery_date  99441 non-null  str
#  8   customer_unique_id             99441 non-null  str
#  9   customer_zip_code_prefix       99441 non-null  int64
#  10  customer_city                  99441 non-null  str
#  11  customer_state                 99441 non-null  str
# dtypes: int64(1), str(11)
# memory usage: 9.1 MB

# %%
merged_df = merged_df.merge(
    order_items,
    on="order_id",
    how="left"
)

# %%
merged_df.shape
# Out:
# (113425, 18)

# %%
merged_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 113425 entries, 0 to 113424
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       113425 non-null  str
#  1   customer_id                    113425 non-null  str
#  2   order_status                   113425 non-null  str
#  3   order_purchase_timestamp       113425 non-null  str
#  4   order_approved_at              113264 non-null  str
#  5   order_delivered_carrier_date   111457 non-null  str
#  6   order_delivered_customer_date  110196 non-null  str
#  7   order_estimated_delivery_date  113425 non-null  str
#  8   customer_unique_id             113425 non-null  str
#  9   customer_zip_code_prefix       113425 non-null  int64
#  10  customer_city                  113425 non-null  str
#  11  customer_state                 113425 non-null  str
#  12  order_item_id                  112650 non-null  float64
#  13  product_id                     112650 non-null  str
#  14  seller_id                      112650 non-null  str
#  15  shipping_limit_date            112650 non-null  str
#  16  price                          112650 non-null  float64
#  17  freight_value                  112650 non-null  float64
# dtypes: float64(3), int64(1), str(14)
# memory usage: 15.6 MB

# %%
merged_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date                customer_unique_id  \
# 0                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 1                    2018-08-13  af07308b275d755c9edb36a90c618231
# 2                    2018-09-04  3a653a41f6f9fc3d2a113cf8398680e8
# 3                    2017-12-15  7c142cf63193a1473d2e66489a9ae977
# 4                    2018-02-26  72632f0f9dd73dfee390c9b22eb56dd6
#
#    customer_zip_code_prefix            customer_city customer_state  \
# 0                      3149                sao paulo             SP
# 1                     47813                barreiras             BA
# 2                     75265               vianopolis             GO
# 3                     59296  sao goncalo do amarante             RN
# 4                      9195              santo andre             SP
#
#    order_item_id                        product_id  \
# 0            1.0  87285b34884572647811a353c7ac498a
# 1            1.0  595fac2a385ac33a80bd5114aec74eb8
# 2            1.0  aa4383b373c6aca5d8797843e5594415
# 3            1.0  d0b61bfb1de832b15ba9d266ca96e5b0
# 4            1.0  65266b2da20d04dbe00c5c2d3bb7859e
#
#                           seller_id  shipping_limit_date   price  \
# 0  3504c0cb71d7fa48d967e0e4c94d59d9  2017-10-06 11:07:15   29.99
# 1  289cdb325fb7e7f891c38608bf9e0962  2018-07-30 03:24:27  118.70
# 2  4869f7a5dfa277a7dca6462dcf3b52b2  2018-08-13 08:55:23  159.90
# 3  66922902710d126a0e7d26b0e3805106  2017-11-23 19:45:59   45.00
# 4  2c9e548be18521d1c43cde1c582c6de8  2018-02-19 20:31:37   19.90
#
#    freight_value
# 0           8.72
# 1          22.76
# 2          19.22
# 3          27.20
# 4           8.72

# %%
merged_df = merged_df.merge(
    products,
    on="product_id",
    how="left"
)

# %%
merged_df.shape
# Out:
# (113425, 26)

# %%
merged_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 113425 entries, 0 to 113424
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       113425 non-null  str
#  1   customer_id                    113425 non-null  str
#  2   order_status                   113425 non-null  str
#  3   order_purchase_timestamp       113425 non-null  str
#  4   order_approved_at              113264 non-null  str
#  5   order_delivered_carrier_date   111457 non-null  str
#  6   order_delivered_customer_date  110196 non-null  str
#  7   order_estimated_delivery_date  113425 non-null  str
#  8   customer_unique_id             113425 non-null  str
#  9   customer_zip_code_prefix       113425 non-null  int64
#  10  customer_city                  113425 non-null  str
#  11  customer_state                 113425 non-null  str
#  12  order_item_id                  112650 non-null  float64
#  13  product_id                     112650 non-null  str
#  14  seller_id                      112650 non-null  str
#  15  shipping_limit_date            112650 non-null  str
#  16  price                          112650 non-null  float64
#  17  freight_value                  112650 non-null  float64
#  18  product_category_name          111047 non-null  str
#  19  product_name_length            111047 non-null  float64
#  20  product_description_length     111047 non-null  float64
#  21  product_photos_qty             111047 non-null  float64
#  22  product_weight_g               112632 non-null  float64
#  23  product_length_cm              112632 non-null  float64
#  24  product_height_cm              112632 non-null  float64
#  25  product_width_cm               112632 non-null  float64
# dtypes: float64(10), int64(1), str(15)
# memory usage: 22.5 MB

# %%
merged_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date                customer_unique_id  \
# 0                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 1                    2018-08-13  af07308b275d755c9edb36a90c618231
# 2                    2018-09-04  3a653a41f6f9fc3d2a113cf8398680e8
# 3                    2017-12-15  7c142cf63193a1473d2e66489a9ae977
# 4                    2018-02-26  72632f0f9dd73dfee390c9b22eb56dd6
#
#    customer_zip_code_prefix  ...   price freight_value  product_category_name  \
# 0                      3149  ...   29.99          8.72  utilidades_domesticas
# 1                     47813  ...  118.70         22.76             perfumaria
# 2                     75265  ...  159.90         19.22             automotivo
# 3                     59296  ...   45.00         27.20               pet_shop
# 4                      9195  ...   19.90          8.72              papelaria
#
#   product_name_length product_description_length product_photos_qty  \
# 0                40.0                      268.0                4.0
# 1                29.0                      178.0                1.0
# 2                46.0                      232.0                1.0
# 3                59.0                      468.0                3.0
# 4                38.0                      316.0                4.0
#
#    product_weight_g  product_length_cm product_height_cm  product_width_cm
# 0             500.0               19.0               8.0              13.0
# 1             400.0               19.0              13.0              19.0
# 2             420.0               24.0              19.0              21.0
# 3             450.0               30.0              10.0              20.0
# 4             250.0               51.0              15.0              15.0
#
# [5 rows x 26 columns]

# %%
merged_df = merged_df.merge(
    payments,
    on="order_id",
    how="left"
)

# %%
merged_df.shape
# Out:
# (118434, 30)

# %%
merged_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 118434 entries, 0 to 118433
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       118434 non-null  str
#  1   customer_id                    118434 non-null  str
#  2   order_status                   118434 non-null  str
#  3   order_purchase_timestamp       118434 non-null  str
#  4   order_approved_at              118258 non-null  str
#  5   order_delivered_carrier_date   116360 non-null  str
#  6   order_delivered_customer_date  115037 non-null  str
#  7   order_estimated_delivery_date  118434 non-null  str
#  8   customer_unique_id             118434 non-null  str
#  9   customer_zip_code_prefix       118434 non-null  int64
#  10  customer_city                  118434 non-null  str
#  11  customer_state                 118434 non-null  str
#  12  order_item_id                  117604 non-null  float64
#  13  product_id                     117604 non-null  str
#  14  seller_id                      117604 non-null  str
#  15  shipping_limit_date            117604 non-null  str
#  16  price                          117604 non-null  float64
#  17  freight_value                  117604 non-null  float64
#  18  product_category_name          115906 non-null  str
#  19  product_name_length            115906 non-null  float64
#  20  product_description_length     115906 non-null  float64
#  21  product_photos_qty             115906 non-null  float64
#  22  product_weight_g               117584 non-null  float64
#  23  product_length_cm              117584 non-null  float64
#  24  product_height_cm              117584 non-null  float64
#  25  product_width_cm               117584 non-null  float64
#  26  payment_sequential             118431 non-null  float64
#  27  payment_type                   118431 non-null  str
#  28  payment_installments           118431 non-null  float64
#  29  payment_value                  118431 non-null  float64
# dtypes: float64(13), int64(1), str(16)
# memory usage: 27.1 MB

# %%
merged_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date                customer_unique_id  \
# 0                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 1                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 2                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 3                    2018-08-13  af07308b275d755c9edb36a90c618231
# 4                    2018-09-04  3a653a41f6f9fc3d2a113cf8398680e8
#
#    customer_zip_code_prefix  ... product_description_length  \
# 0                      3149  ...                      268.0
# 1                      3149  ...                      268.0
# 2                      3149  ...                      268.0
# 3                     47813  ...                      178.0
# 4                     75265  ...                      232.0
#
#   product_photos_qty  product_weight_g product_length_cm product_height_cm  \
# 0                4.0             500.0              19.0               8.0
# 1                4.0             500.0              19.0               8.0
# 2                4.0             500.0              19.0               8.0
# 3                1.0             400.0              19.0              13.0
# 4                1.0             420.0              24.0              19.0
#
#   product_width_cm  payment_sequential  payment_type payment_installments  \
# 0             13.0                 1.0   credit_card                  1.0
# 1             13.0                 3.0       voucher                  1.0
# 2             13.0                 2.0       voucher                  1.0
# 3             19.0                 1.0        boleto                  1.0
# 4             21.0                 1.0   credit_card                  3.0
#
#    payment_value
# 0          18.12
# 1           2.00
# 2          18.59
# 3         141.46
# 4         179.12
#
# [5 rows x 30 columns]

# %%
merged_df = merged_df.merge(
    reviews,
    on="order_id",
    how="left"
)

# %%
merged_df.shape
# Out:
# (119143, 36)

# %%
merged_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 119143 entries, 0 to 119142
# Data columns (total 36 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       119143 non-null  str
#  1   customer_id                    119143 non-null  str
#  2   order_status                   119143 non-null  str
#  3   order_purchase_timestamp       119143 non-null  str
#  4   order_approved_at              118966 non-null  str
#  5   order_delivered_carrier_date   117057 non-null  str
#  6   order_delivered_customer_date  115722 non-null  str
#  7   order_estimated_delivery_date  119143 non-null  str
#  8   customer_unique_id             119143 non-null  str
#  9   customer_zip_code_prefix       119143 non-null  int64
#  10  customer_city                  119143 non-null  str
#  11  customer_state                 119143 non-null  str
#  12  order_item_id                  118310 non-null  float64
#  13  product_id                     118310 non-null  str
#  14  seller_id                      118310 non-null  str
#  15  shipping_limit_date            118310 non-null  str
#  16  price                          118310 non-null  float64
#  17  freight_value                  118310 non-null  float64
#  18  product_category_name          116601 non-null  str
#  19  product_name_length            116601 non-null  float64
#  20  product_description_length     116601 non-null  float64
#  21  product_photos_qty             116601 non-null  float64
#  22  product_weight_g               118290 non-null  float64
#  23  product_length_cm              118290 non-null  float64
#  24  product_height_cm              118290 non-null  float64
#  25  product_width_cm               118290 non-null  float64
#  26  payment_sequential             119140 non-null  float64
#  27  payment_type                   119140 non-null  str
#  28  payment_installments           119140 non-null  float64
#  29  payment_value                  119140 non-null  float64
#  30  review_id                      118146 non-null  str
#  31  review_score                   118146 non-null  float64
#  32  review_comment_title           118144 non-null  str
#  33  review_comment_message         118115 non-null  str
#  34  review_creation_date           118146 non-null  str
#  35  review_answer_timestamp        118146 non-null  str
# dtypes: float64(14), int64(1), str(21)
# memory usage: 32.7 MB

# %%
merged_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date                customer_unique_id  \
# 0                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 1                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 2                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 3                    2018-08-13  af07308b275d755c9edb36a90c618231
# 4                    2018-09-04  3a653a41f6f9fc3d2a113cf8398680e8
#
#    customer_zip_code_prefix  ... payment_sequential payment_type  \
# 0                      3149  ...                1.0  credit_card
# 1                      3149  ...                3.0      voucher
# 2                      3149  ...                2.0      voucher
# 3                     47813  ...                1.0       boleto
# 4                     75265  ...                1.0  credit_card
#
#    payment_installments payment_value                         review_id  \
# 0                   1.0         18.12  a54f0611adc9ed256b57ede6b6eb5114
# 1                   1.0          2.00  a54f0611adc9ed256b57ede6b6eb5114
# 2                   1.0         18.59  a54f0611adc9ed256b57ede6b6eb5114
# 3                   1.0        141.46  8d5266042046a06655c8db133d120ba5
# 4                   3.0        179.12  e73b67b67587f7644d5bd1a52deb1b01
#
#   review_score  review_comment_title  \
# 0          4.0              No Title
# 1          4.0              No Title
# 2          4.0              No Title
# 3          4.0      Muito boa a loja
# 4          5.0              No Title
#
#                               review_comment_message review_creation_date  \
# 0  Não testei o produto ainda, mas ele veio corre...  2017-10-11 00:00:00
# 1  Não testei o produto ainda, mas ele veio corre...  2017-10-11 00:00:00
# 2  Não testei o produto ainda, mas ele veio corre...  2017-10-11 00:00:00
# 3                               Muito bom o produto.  2018-08-08 00:00:00
# 4                                         No Comment  2018-08-18 00:00:00
#
#    review_answer_timestamp
# 0      2017-10-12 03:43:48
# 1      2017-10-12 03:43:48
# 2      2017-10-12 03:43:48
# 3      2018-08-08 18:37:50
# 4      2018-08-22 19:07:58
#
# [5 rows x 36 columns]

# %%
merged_df = merged_df.merge(
    sellers,
    on="seller_id",
    how="left"
)

# %%
merged_df.shape
# Out:
# (119143, 39)

# %%
merged_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 119143 entries, 0 to 119142
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       119143 non-null  str
#  1   customer_id                    119143 non-null  str
#  2   order_status                   119143 non-null  str
#  3   order_purchase_timestamp       119143 non-null  str
#  4   order_approved_at              118966 non-null  str
#  5   order_delivered_carrier_date   117057 non-null  str
#  6   order_delivered_customer_date  115722 non-null  str
#  7   order_estimated_delivery_date  119143 non-null  str
#  8   customer_unique_id             119143 non-null  str
#  9   customer_zip_code_prefix       119143 non-null  int64
#  10  customer_city                  119143 non-null  str
#  11  customer_state                 119143 non-null  str
#  12  order_item_id                  118310 non-null  float64
#  13  product_id                     118310 non-null  str
#  14  seller_id                      118310 non-null  str
#  15  shipping_limit_date            118310 non-null  str
#  16  price                          118310 non-null  float64
#  17  freight_value                  118310 non-null  float64
#  18  product_category_name          116601 non-null  str
#  19  product_name_length            116601 non-null  float64
#  20  product_description_length     116601 non-null  float64
#  21  product_photos_qty             116601 non-null  float64
#  22  product_weight_g               118290 non-null  float64
#  23  product_length_cm              118290 non-null  float64
#  24  product_height_cm              118290 non-null  float64
#  25  product_width_cm               118290 non-null  float64
#  26  payment_sequential             119140 non-null  float64
#  27  payment_type                   119140 non-null  str
#  28  payment_installments           119140 non-null  float64
#  29  payment_value                  119140 non-null  float64
#  30  review_id                      118146 non-null  str
#  31  review_score                   118146 non-null  float64
#  32  review_comment_title           118144 non-null  str
#  33  review_comment_message         118115 non-null  str
#  34  review_creation_date           118146 non-null  str
#  35  review_answer_timestamp        118146 non-null  str
#  36  seller_zip_code_prefix         118310 non-null  float64
#  37  seller_city                    118310 non-null  str
#  38  seller_state                   118310 non-null  str
# dtypes: float64(15), int64(1), str(23)
# memory usage: 35.5 MB

# %%
merged_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date                customer_unique_id  \
# 0                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 1                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 2                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 3                    2018-08-13  af07308b275d755c9edb36a90c618231
# 4                    2018-09-04  3a653a41f6f9fc3d2a113cf8398680e8
#
#    customer_zip_code_prefix  ... payment_value  \
# 0                      3149  ...         18.12
# 1                      3149  ...          2.00
# 2                      3149  ...         18.59
# 3                     47813  ...        141.46
# 4                     75265  ...        179.12
#
#                           review_id  review_score review_comment_title  \
# 0  a54f0611adc9ed256b57ede6b6eb5114           4.0             No Title
# 1  a54f0611adc9ed256b57ede6b6eb5114           4.0             No Title
# 2  a54f0611adc9ed256b57ede6b6eb5114           4.0             No Title
# 3  8d5266042046a06655c8db133d120ba5           4.0     Muito boa a loja
# 4  e73b67b67587f7644d5bd1a52deb1b01           5.0             No Title
#
#                               review_comment_message review_creation_date  \
# 0  Não testei o produto ainda, mas ele veio corre...  2017-10-11 00:00:00
# 1  Não testei o produto ainda, mas ele veio corre...  2017-10-11 00:00:00
# 2  Não testei o produto ainda, mas ele veio corre...  2017-10-11 00:00:00
# 3                               Muito bom o produto.  2018-08-08 00:00:00
# 4                                         No Comment  2018-08-18 00:00:00
#
#    review_answer_timestamp  seller_zip_code_prefix     seller_city  \
# 0      2017-10-12 03:43:48                  9350.0            maua
# 1      2017-10-12 03:43:48                  9350.0            maua
# 2      2017-10-12 03:43:48                  9350.0            maua
# 3      2018-08-08 18:37:50                 31570.0  belo horizonte
# 4      2018-08-22 19:07:58                 14840.0         guariba
#
#    seller_state
# 0            SP
# 1            SP
# 2            SP
# 3            SP
# 4            SP
#
# [5 rows x 39 columns]

# %%
merged_df = merged_df.merge(
   category_translation,
    on="product_category_name",
    how="left"
)

# %%
merged_df.shape
# Out:
# (119143, 40)

# %%
merged_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 119143 entries, 0 to 119142
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       119143 non-null  str
#  1   customer_id                    119143 non-null  str
#  2   order_status                   119143 non-null  str
#  3   order_purchase_timestamp       119143 non-null  str
#  4   order_approved_at              118966 non-null  str
#  5   order_delivered_carrier_date   117057 non-null  str
#  6   order_delivered_customer_date  115722 non-null  str
#  7   order_estimated_delivery_date  119143 non-null  str
#  8   customer_unique_id             119143 non-null  str
#  9   customer_zip_code_prefix       119143 non-null  int64
#  10  customer_city                  119143 non-null  str
#  11  customer_state                 119143 non-null  str
#  12  order_item_id                  118310 non-null  float64
#  13  product_id                     118310 non-null  str
#  14  seller_id                      118310 non-null  str
#  15  shipping_limit_date            118310 non-null  str
#  16  price                          118310 non-null  float64
#  17  freight_value                  118310 non-null  float64
#  18  product_category_name          116601 non-null  str
#  19  product_name_length            116601 non-null  float64
#  20  product_description_length     116601 non-null  float64
#  21  product_photos_qty             116601 non-null  float64
#  22  product_weight_g               118290 non-null  float64
#  23  product_length_cm              118290 non-null  float64
#  24  product_height_cm              118290 non-null  float64
#  25  product_width_cm               118290 non-null  float64
#  26  payment_sequential             119140 non-null  float64
#  27  payment_type                   119140 non-null  str
#  28  payment_installments           119140 non-null  float64
#  29  payment_value                  119140 non-null  float64
#  30  review_id                      118146 non-null  str
#  31  review_score                   118146 non-null  float64
#  32  review_comment_title           118144 non-null  str
#  33  review_comment_message         118115 non-null  str
#  34  review_creation_date           118146 non-null  str
#  35  review_answer_timestamp        118146 non-null  str
#  36  seller_zip_code_prefix         118310 non-null  float64
#  37  seller_city                    118310 non-null  str
#  38  seller_state                   118310 non-null  str
#  39  product_category_name_english  116576 non-null  str
# dtypes: float64(15), int64(1), str(24)
# memory usage: 36.4 MB

# %%
merged_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date                customer_unique_id  \
# 0                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 1                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 2                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 3                    2018-08-13  af07308b275d755c9edb36a90c618231
# 4                    2018-09-04  3a653a41f6f9fc3d2a113cf8398680e8
#
#    customer_zip_code_prefix  ...                         review_id  \
# 0                      3149  ...  a54f0611adc9ed256b57ede6b6eb5114
# 1                      3149  ...  a54f0611adc9ed256b57ede6b6eb5114
# 2                      3149  ...  a54f0611adc9ed256b57ede6b6eb5114
# 3                     47813  ...  8d5266042046a06655c8db133d120ba5
# 4                     75265  ...  e73b67b67587f7644d5bd1a52deb1b01
#
#   review_score  review_comment_title  \
# 0          4.0              No Title
# 1          4.0              No Title
# 2          4.0              No Title
# 3          4.0      Muito boa a loja
# 4          5.0              No Title
#
#                               review_comment_message review_creation_date  \
# 0  Não testei o produto ainda, mas ele veio corre...  2017-10-11 00:00:00
# 1  Não testei o produto ainda, mas ele veio corre...  2017-10-11 00:00:00
# 2  Não testei o produto ainda, mas ele veio corre...  2017-10-11 00:00:00
# 3                               Muito bom o produto.  2018-08-08 00:00:00
# 4                                         No Comment  2018-08-18 00:00:00
#
#   review_answer_timestamp  seller_zip_code_prefix     seller_city  \
# 0     2017-10-12 03:43:48                  9350.0            maua
# 1     2017-10-12 03:43:48                  9350.0            maua
# 2     2017-10-12 03:43:48                  9350.0            maua
# 3     2018-08-08 18:37:50                 31570.0  belo horizonte
# 4     2018-08-22 19:07:58                 14840.0         guariba
#
#   seller_state  product_category_name_english
# 0           SP                     housewares
# 1           SP                     housewares
# 2           SP                     housewares
# 3           SP                      perfumery
# 4           SP                           auto
#
# [5 rows x 40 columns]

# %%
merged_df.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 177
# order_delivered_carrier_date     2086
# order_delivered_customer_date    3421
# order_estimated_delivery_date       0
# customer_unique_id                  0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# order_item_id                     833
# product_id                        833
# seller_id                         833
# shipping_limit_date               833
# price                             833
# freight_value                     833
# product_category_name            2542
# product_name_length              2542
# product_description_length       2542
# product_photos_qty               2542
# product_weight_g                  853
# product_length_cm                 853
# product_height_cm                 853
# product_width_cm                  853
# payment_sequential                  3
# payment_type                        3
# payment_installments                3
# payment_value                       3
# review_id                         997
# review_score                      997
# review_comment_title              999
# review_comment_message           1028
# review_creation_date              997
# review_answer_timestamp           997
# seller_zip_code_prefix            833
# seller_city                       833
# seller_state                      833
# product_category_name_english    2567
# dtype: int64

# %%
merged_df.loc[
    merged_df["price"].isnull(),
    ["order_id", "order_status"]
].head(20)
# Out:
#                               order_id order_status
# 319   8e24261a7e58791d10cb1bf9da94df5c  unavailable
# 702   c272bcd21c287498b4883c7512019702  unavailable
# 828   37553832a3a89c9b2db59701c357ca67  unavailable
# 887   d57e15fb07fd180f06ab3926b39edcd2  unavailable
# 1362  00b1cb0320190ca0daa2c88b35206009     canceled
# 1395  2f634e2cebf8c0283e7ef0989f77d217  unavailable
# 1897  ee0db22a8e742b752914016708470ec8  unavailable
# 2142  ed3efbd3a87bea76c2812c66a0b32219     canceled
# 2180  6ad57aecbae806a7e9cc2cdb6b380711  unavailable
# 2232  df8282afe61008dc26c6c31011474d02     canceled
# 2429  8d4c637f1accf7a88a4555f02741e606     canceled
# 2570  9f3458f0433d4cfa472f4682654b8d49  unavailable
# 2586  7a9d4c7f9b068337875b95465330f2fc     canceled
# 2750  f0df036e9be21fc238f131bbfcdde769  unavailable
# 2771  86f0bcd9b426a2c1022ae317c7f27be6  unavailable
# 3178  98fe01bc254b759c1f2c11d77c2891d5  unavailable
# 3179  98fe01bc254b759c1f2c11d77c2891d5  unavailable
# 3209  f56dc9034c3962e36d49fb73baa12800  unavailable
# 3535  0130f0f71fb0e831d18e6a3b33a3a50c  unavailable
# 3642  ddaec6fff982b13e7e048b627a11d6da     canceled

# %%
merged_df.loc[
    merged_df["price"].isnull(),
    [
        "order_id",
        "order_status",
        "product_id",
        "seller_id",
        "price",
        "payment_value",
        "review_score"
    ]
].head(20)
# Out:
#                               order_id order_status product_id seller_id  \
# 319   8e24261a7e58791d10cb1bf9da94df5c  unavailable        NaN       NaN
# 702   c272bcd21c287498b4883c7512019702  unavailable        NaN       NaN
# 828   37553832a3a89c9b2db59701c357ca67  unavailable        NaN       NaN
# 887   d57e15fb07fd180f06ab3926b39edcd2  unavailable        NaN       NaN
# 1362  00b1cb0320190ca0daa2c88b35206009     canceled        NaN       NaN
# 1395  2f634e2cebf8c0283e7ef0989f77d217  unavailable        NaN       NaN
# 1897  ee0db22a8e742b752914016708470ec8  unavailable        NaN       NaN
# 2142  ed3efbd3a87bea76c2812c66a0b32219     canceled        NaN       NaN
# 2180  6ad57aecbae806a7e9cc2cdb6b380711  unavailable        NaN       NaN
# 2232  df8282afe61008dc26c6c31011474d02     canceled        NaN       NaN
# 2429  8d4c637f1accf7a88a4555f02741e606     canceled        NaN       NaN
# 2570  9f3458f0433d4cfa472f4682654b8d49  unavailable        NaN       NaN
# 2586  7a9d4c7f9b068337875b95465330f2fc     canceled        NaN       NaN
# 2750  f0df036e9be21fc238f131bbfcdde769  unavailable        NaN       NaN
# 2771  86f0bcd9b426a2c1022ae317c7f27be6  unavailable        NaN       NaN
# 3178  98fe01bc254b759c1f2c11d77c2891d5  unavailable        NaN       NaN
# 3179  98fe01bc254b759c1f2c11d77c2891d5  unavailable        NaN       NaN
# 3209  f56dc9034c3962e36d49fb73baa12800  unavailable        NaN       NaN
# 3535  0130f0f71fb0e831d18e6a3b33a3a50c  unavailable        NaN       NaN
# 3642  ddaec6fff982b13e7e048b627a11d6da     canceled        NaN       NaN
#
#       price  payment_value  review_score
# 319     NaN          84.00           1.0
# 702     NaN          97.68           3.0
# 828     NaN         132.46           1.0
# 887     NaN         134.38           1.0
# 1362    NaN           0.00           1.0
# 1395    NaN         615.53           1.0
# 1897    NaN         167.82           1.0
# 2142    NaN         191.46           2.0
# 2180    NaN         161.47           1.0
# 2232    NaN         139.96           3.0
# 2429    NaN          66.44           5.0
# 2570    NaN          78.18           5.0
# 2586    NaN          72.90           5.0
# 2750    NaN          59.74           1.0
# 2771    NaN         177.59           4.0
# 3178    NaN         150.00           1.0
# 3179    NaN          49.06           1.0
# 3209    NaN         205.81           3.0
# 3535    NaN          52.77           1.0
# 3642    NaN         116.99           1.0

# %%
orders.shape
# Out:
# (99441, 8)

# %%
order_items.shape
# Out:
# (112650, 7)

# %%
merged_df.loc[
    merged_df["price"].isnull(),
    "order_status"
].value_counts()
# Out:
# order_status
# unavailable    645
# canceled       180
# created          5
# invoiced         2
# shipped          1
# Name: count, dtype: int64

# %%
merged_df.to_csv(
    "../cleaned/merged_dataset.csv",
    index=False
)

# %%
merged_df.loc[
    merged_df["product_id"].isna(),
    "order_status"
].value_counts()
# Out:
# order_status
# unavailable    645
# canceled       180
# created          5
# invoiced         2
# shipped          1
# Name: count, dtype: int64

# %% [markdown]
# ## Feature 1 – Delivery Time
#
# Delivery Time represents the number of days taken to deliver an order from the purchase date to the customer's delivery date.

# %%
merged_df["delivery_time"] = (
    pd.to_datetime(merged_df["order_delivered_customer_date"]) -
    pd.to_datetime(merged_df["order_purchase_timestamp"])
).dt.days

# %%
merged_df["delivery_time"].describe()
# Out:
# count    115722.000000
# mean         12.022589
# std           9.454922
# min           0.000000
# 25%           6.000000
# 50%          10.000000
# 75%          15.000000
# max         209.000000
# Name: delivery_time, dtype: float64

# %% [markdown]
# ## Feature 2 – Shipping Duration
#
# Shipping Duration represents the number of days taken for the order to move from the seller to the carrier.

# %%
merged_df["shipping_duration"] = (
    pd.to_datetime(merged_df["order_delivered_carrier_date"]) -
    pd.to_datetime(merged_df["shipping_limit_date"])
).dt.days

# %%
merged_df["shipping_duration"].describe()
# Out:
# count    117056.000000
# mean         -3.830098
# std           6.509475
# min       -1055.000000
# 25%          -6.000000
# 50%          -4.000000
# 75%          -2.000000
# max         116.000000
# Name: shipping_duration, dtype: float64

# %% [markdown]
# ## Feature 3 – Order Processing Time
#
# Order Processing Time measures the number of days between order purchase and order approval.

# %%
merged_df["order_processing_time"] = (
    pd.to_datetime(merged_df["order_approved_at"]) -
    pd.to_datetime(merged_df["order_purchase_timestamp"])
).dt.days

# %%
merged_df["order_processing_time"].describe()
# Out:
# count    118966.000000
# mean          0.274465
# std           0.980584
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max         187.000000
# Name: order_processing_time, dtype: float64

# %% [markdown]
# ## Feature 4 – Customer Purchase Count
#
# This feature calculates the total number of purchases made by each customer.

# %%
purchase_count = (
    merged_df.groupby("customer_unique_id")["order_id"]
    .nunique()
    .reset_index(name="customer_purchase_count")
)

merged_df = merged_df.merge(
    purchase_count,
    on="customer_unique_id",
    how="left"
)

# %%
merged_df["customer_purchase_count"].describe()
# Out:
# count    119143.000000
# mean          1.091126
# std           0.410960
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max          17.000000
# Name: customer_purchase_count, dtype: float64

# %% [markdown]
# ## Feature 5 – Repeat Customer Indicator
#
# Customers with more than one purchase are classified as repeat customers.

# %%
merged_df["repeat_customer"] = (
    merged_df["customer_purchase_count"] > 1
).astype(int)

# %%
merged_df["repeat_customer"].value_counts()
# Out:
# repeat_customer
# 0    110404
# 1      8739
# Name: count, dtype: int64

# %% [markdown]
# ## Feature 6 – Customer Lifetime Value
#
# Customer Lifetime Value represents the total revenue generated by each customer.

# %%
customer_ltv = (
    merged_df.groupby("customer_unique_id")["price"]
    .sum()
    .reset_index(name="customer_lifetime_value")
)

merged_df = merged_df.merge(
    customer_ltv,
    on="customer_unique_id",
    how="left"
)

# %%
merged_df["customer_lifetime_value"].describe()
# Out:
# count    119143.000000
# mean        197.546377
# std         445.772704
# min           0.000000
# 25%          50.900000
# 50%          99.990000
# 75%         193.500000
# max       13440.000000
# Name: customer_lifetime_value, dtype: float64

# %% [markdown]
# ## Feature 7 – Total Order Value
#
# Total Order Value is calculated by summing the product price and freight value.

# %%
merged_df["total_order_value"] = (
    merged_df["price"] +
    merged_df["freight_value"]
)

# %%
merged_df["total_order_value"].describe()
# Out:
# count    118310.000000
# mean        140.678990
# std         191.239906
# min           6.080000
# 25%          55.240000
# 50%          91.990000
# 75%         157.615000
# max        6929.310000
# Name: total_order_value, dtype: float64

# %% [markdown]
# ## Feature 8 – Average Product Price
#
# Average Product Price represents the average price of products purchased by each customer.

# %%
avg_price = (
    merged_df.groupby("customer_unique_id")["price"]
    .mean()
    .reset_index(name="average_product_price")
)

merged_df = merged_df.merge(
    avg_price,
    on="customer_unique_id",
    how="left"
)

# %% [markdown]
# ## Feature 9 – Average Review Score
#
# Average Review Score measures customer satisfaction based on review ratings.

# %%
avg_review = (
    merged_df.groupby("customer_unique_id")["review_score"]
    .mean()
    .reset_index(name="average_review_score")
)

merged_df = merged_df.merge(
    avg_review,
    on="customer_unique_id",
    how="left"
)

# %% [markdown]
# ## Feature 10 – Seller Performance Score
#
# Seller Performance Score is calculated using the average review score received by each seller.

# %%
seller_score = (
    merged_df.groupby("seller_id")["review_score"]
    .mean()
    .reset_index(name="seller_performance_score")
)

merged_df = merged_df.merge(
    seller_score,
    on="seller_id",
    how="left"
)

# %% [markdown]
# ## Feature 11 – Revenue per Customer
#
# Revenue per Customer represents the total amount spent by each customer.

# %%
revenue_customer = (
    merged_df.groupby("customer_unique_id")["price"]
    .sum()
    .reset_index(name="revenue_per_customer")
)

merged_df = merged_df.merge(
    revenue_customer,
    on="customer_unique_id",
    how="left"
)

# %% [markdown]
# ## Feature 12 – Monthly Sales
#
# Monthly Sales groups orders by purchase month to analyze sales trends over time.

# %%
merged_df["order_month"] = (
    pd.to_datetime(
        merged_df["order_purchase_timestamp"]
    ).dt.to_period("M").astype(str)
)

# %%
merged_df["order_month"].head()
# Out:
# 0    2017-10
# 1    2017-10
# 2    2017-10
# 3    2018-07
# 4    2018-08
# Name: order_month, dtype: str

# %%
merged_df.to_csv(
    "../cleaned/feature_engineered_dataset.csv",
    index=False
)

# %%
sns.set_theme(
    style="whitegrid",
    palette="Set2",
    font_scale=1.1
)

plt.rcParams["figure.figsize"] = (12, 6)

# %% [markdown]
# ## Monthly Sales Trend
#
# This visualization shows the monthly sales trend based on the total revenue generated from customer purchases.

# %%
monthly_sales = (
    merged_df.groupby("order_month")["price"]
    .sum()
    .reset_index()
)

plt.figure(figsize=(14,6))

sns.lineplot(
    data=monthly_sales,
    x="order_month",
    y="price",
    marker="o",
    linewidth=3,
    color="steelblue"
)

plt.title(
    "Monthly Sales Trend",
    fontsize=18,
    fontweight="bold"
)

plt.xlabel("Order Month", fontsize=12)
plt.ylabel("Total Revenue", fontsize=12)

plt.xticks(rotation=45)

plt.grid(alpha=0.3)

plt.tight_layout()
plt.savefig(
    "../dashboard/static/charts/monthly_sales.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Revenue by State
#
# This visualization shows the total revenue generated from each customer state.

# %%
revenue_state = (
    merged_df.groupby("customer_state")["price"]
    .sum()
    .sort_values(ascending=False)
    .reset_index()
)

plt.figure(figsize=(15, 8))

sns.barplot(
    data=revenue_state,
    x="customer_state",
    y="price",
    hue="customer_state",
    palette="viridis",
    legend=False
)

plt.title(
    "Revenue by State",
    fontsize=18,
    fontweight="bold"
)

plt.xlabel("Revenue")
plt.ylabel("State")

plt.tight_layout()
plt.savefig("../dashboard/static/charts/monthly_sales.png",
            dpi=300,
            bbox_inches="tight")

plt.show()

plt.show()

# %%
category_sales = (
    merged_df.groupby("product_category_name_english")["price"]
    .sum()
    .sort_values(ascending=False)
    .head(15)
    .reset_index()
)

plt.figure(figsize=(15, 8))

sns.barplot(
    data=category_sales,
    x="product_category_name_english",
    y="price",
    hue="product_category_name_english",
    palette="rocket",
    legend=False
)

plt.title(
    "Top 15 Revenue by Product Category",
    fontsize=18,
    fontweight="bold"
)

plt.xlabel("Product Category")
plt.ylabel("Revenue")

plt.xticks(rotation=45, ha="right")

plt.tight_layout()

plt.show()

# %%
average_order = (
    merged_df.groupby("order_id")["total_order_value"]
    .sum()
    .mean()
)

plt.figure(figsize=(6,6))

plt.bar(
    ["Average Order Value"],
    [average_order],
    color="teal",
    width=0.5
)

plt.title(
    "Average Order Value",
    fontsize=18,
    fontweight="bold"
)

plt.ylabel("Average Value")

plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(12,6))

sns.countplot(
    data=merged_df,
    x="customer_state",
    hue="customer_state",
    order=merged_df["customer_state"].value_counts().index,
    palette="Set2",
    
)

plt.title(
    "Customer Distribution by State",
    fontsize=18,
    fontweight="bold"
)

plt.xlabel("State")
plt.ylabel("Number of Customers")

plt.xticks(rotation=90)

plt.tight_layout()

plt.show()

# %%
repeat = (
    merged_df["repeat_customer"]
    .value_counts()
)

labels = ["One-Time", "Repeat"]

plt.figure(figsize=(7,7))

plt.pie(
    repeat,
    labels=labels,
    autopct="%1.1f%%",
    startangle=90,
    explode=[0,0.05]
)

plt.title(
    "Repeat Customer Distribution",
    fontsize=18,
    fontweight="bold"
)

plt.tight_layout()

plt.show()

# %%
top_customers = (
    merged_df.groupby("customer_unique_id", as_index=False)["total_order_value"]
    .sum()
    .sort_values(by="total_order_value", ascending=False)
    .head(10)
)

plt.figure(figsize=(14,7))

sns.barplot(
    data=top_customers,
    x="total_order_value",
    y="customer_unique_id",
    hue="customer_unique_id",
    palette="viridis",
    legend=False
)

plt.title("Top 10 Customers by Spending", fontsize=18, fontweight="bold")
plt.xlabel("Total Spending")
plt.ylabel("Customer ID")

plt.tight_layout()
plt.show()

# %%
best_products = (
    merged_df.groupby(
        "product_category_name_english",
        as_index=False
    )["order_item_id"]
    .count()
    .sort_values(by="order_item_id", ascending=False)
    .head(10)
)

plt.figure(figsize=(14,6))

sns.barplot(
    data=best_products,
    x="order_item_id",
    y="product_category_name_english",
    hue="product_category_name_english",
    palette="rocket",
    legend=False
)

plt.title("Top 10 Best Selling Product Categories", fontsize=18, fontweight="bold")
plt.xlabel("Products Sold")
plt.ylabel("Category")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))

sns.histplot(
    data=merged_df,
    x="price",
    bins=40,
    kde=True,
    color="steelblue"
)

plt.title("Product Price Distribution", fontsize=18, fontweight="bold")
plt.xlabel("Price")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,5))

sns.boxplot(
    data=merged_df,
    x="price",
    color="tomato"
)

plt.title("Product Price Outliers", fontsize=18, fontweight="bold")
plt.xlabel("Price")

plt.tight_layout()
plt.show()

# %%
seller_performance = (
    merged_df.groupby("seller_id", as_index=False)["price"]
    .sum()
    .sort_values(by="price", ascending=False)
    .head(10)
)

plt.figure(figsize=(14,6))

sns.barplot(
    data=seller_performance,
    x="price",
    y="seller_id",
    hue="seller_id",
    palette="crest",
    legend=False
)

plt.title("Top 10 Seller Performance", fontsize=18, fontweight="bold")
plt.xlabel("Revenue")
plt.ylabel("Seller ID")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))

sns.histplot(
    data=merged_df,
    x="delivery_time",
    bins=30,
    kde=True,
    color="green"
)

plt.title("Delivery Time Distribution", fontsize=18, fontweight="bold")
plt.xlabel("Delivery Time (Days)")
plt.ylabel("Orders")

plt.tight_layout()
plt.show()

# %%
merged_df["delayed_delivery"] = (
    merged_df["order_delivered_customer_date"] >
    merged_df["order_estimated_delivery_date"]
)

plt.figure(figsize=(6,6))

sns.countplot(
    data=merged_df,
    x="delayed_delivery",
    hue="delayed_delivery",
    palette="Set2",
    legend=False
)

plt.title("Delayed Deliveries", fontsize=18, fontweight="bold")
plt.xlabel("Delayed")
plt.ylabel("Orders")

plt.tight_layout()
plt.show()

# %%
payment = (
    merged_df["payment_type"]
    .value_counts()
)

plt.figure(figsize=(10,10))

plt.pie(
    payment,
    labels=payment.index,
    autopct="%1.1f%%",
    startangle=10
)

plt.title("Payment Methods", fontsize=18, fontweight="bold")
plt.show()

# %%
plt.figure(figsize=(12,6))

sns.countplot(
    data=merged_df,
    x="payment_installments",
    hue="payment_type",
    palette="Set2"
)

plt.title("Installment Analysis by Payment Type", fontsize=18, fontweight="bold")
plt.xlabel("Installments")
plt.ylabel("Number of Orders")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))

sns.countplot(
    data=merged_df,
    x="review_score",
    hue="review_score",
    palette="viridis",
    legend=False
)

plt.title("Review Score Distribution", fontsize=18, fontweight="bold")
plt.xlabel("Review Score")
plt.ylabel("Count")

plt.tight_layout()
plt.show()

# %%
merged_df["review_sentiment"] = merged_df["review_score"].apply(
    lambda x: "Positive" if x >= 4 else "Negative"
)

review_sentiment = (
    merged_df["review_sentiment"]
    .value_counts()
)

plt.figure(figsize=(7,7))

plt.pie(
    review_sentiment,
    labels=review_sentiment.index,
    autopct="%1.1f%%",
    explode=[0.03, 0.06],
    startangle=90
)

plt.title("Positive vs Negative Reviews", fontsize=18, fontweight="bold")

plt.show()

# %%
plt.figure(figsize=(12,8))

numeric_data = merged_df.select_dtypes(include=["number"])

sns.heatmap(
    numeric_data.corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
    linewidths=0.5
)

plt.title("Correlation Heatmap", fontsize=18, fontweight="bold")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14,10))

corr_columns = [
    "price",
    "freight_value",
    "payment_value",
    "payment_installments",
    "review_score",
    "delivery_time",
    "shipping_duration",
    "order_processing_time",
    "customer_purchase_count",
    "customer_lifetime_value",
    "total_order_value",
    "average_product_price",
    "seller_performance_score",
    "revenue_per_customer"
]

corr = merged_df[corr_columns].corr()

sns.heatmap(
    corr,
    annot=True,
    fmt=".2f",
    cmap="RdYlBu_r",
    square=True,
    linewidths=0.5,
    linecolor="white",
    cbar_kws={"shrink":0.8},
    annot_kws={"size":10}
)

plt.title(
    "Correlation Heatmap of Business Features",
    fontsize=18,
    fontweight="bold",
    pad=20
)

plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)

plt.tight_layout()

plt.show()

# %% [markdown]
# # Phase 5 – Data Quality Report
#
# ## Overview
#
# This phase summarizes the entire data preprocessing pipeline. It includes:
#
# - Records Processed
# - Missing Values Handled
# - Duplicate Records Removed
# - Outliers Detected
# - Outliers Removed
# - Features Created
# - Tables Merged
# - Final Dataset Dimensions
#
# Finally, the feature-engineered dataset and the data quality report are exported for further analysis and dashboard development.

# %% [markdown]
# ## Records Processed
#
# The final merged dataset contains the following number of rows and columns after preprocessing and feature engineering.

# %%
print("Final Dataset Shape")
print(merged_df.shape)

rows = merged_df.shape[0]
columns = merged_df.shape[1]

print(f"Rows    : {rows}")
print(f"Columns : {columns}")
# Out:
# Final Dataset Shape
# (119143, 54)
# Rows    : 119143
# Columns : 54

# %% [markdown]
# ## Missing Values Summary
#
# The remaining missing values are analyzed after merging all datasets.
# Most missing values represent valid business scenarios such as cancelled orders, unavailable products, or customers who did not leave reviews.

# %%
missing_report = pd.DataFrame({
    "Column": merged_df.columns,
    "Missing Values": merged_df.isnull().sum(),
    "Percentage (%)": (
        merged_df.isnull().mean() * 100
    ).round(2)
})

missing_report
# Out:
#                                                       Column  Missing Values  \
# order_id                                            order_id               0
# customer_id                                      customer_id               0
# order_status                                    order_status               0
# order_purchase_timestamp            order_purchase_timestamp               0
# order_approved_at                          order_approved_at             177
# order_delivered_carrier_date    order_delivered_carrier_date            2086
# order_delivered_customer_date  order_delivered_customer_date            3421
# order_estimated_delivery_date  order_estimated_delivery_date               0
# customer_unique_id                        customer_unique_id               0
# customer_zip_code_prefix            customer_zip_code_prefix               0
# customer_city                                  customer_city               0
# customer_state                                customer_state               0
# order_item_id                                  order_item_id             833
# product_id                                        product_id             833
# seller_id                                          seller_id             833
# shipping_limit_date                      shipping_limit_date             833
# price                                                  price             833
# freight_value                                  freight_value             833
# product_category_name                  product_category_name            2542
# product_name_length                      product_name_length            2542
# product_description_length        product_description_length            2542
# product_photos_qty                        product_photos_qty            2542
# product_weight_g                            product_weight_g             853
# product_length_cm                          product_length_cm             853
# product_height_cm                          product_height_cm             853
# product_width_cm                            product_width_cm             853
# payment_sequential                        payment_sequential               3
# payment_type                                    payment_type               3
# payment_installments                    payment_installments               3
# payment_value                                  payment_value               3
# review_id                                          review_id             997
# review_score                                    review_score             997
# review_comment_title                    review_comment_title             999
# review_comment_message                review_comment_message            1028
# review_creation_date                    review_creation_date             997
# review_answer_timestamp              review_answer_timestamp             997
# seller_zip_code_prefix                seller_zip_code_prefix             833
# seller_city                                      seller_city             833
# seller_state                                    seller_state             833
# product_category_name_english  product_category_name_english            2567
# delivery_time                                  delivery_time            3421
# shipping_duration                          shipping_duration            2087
# order_processing_time                  order_processing_time             177
# customer_purchase_count              customer_purchase_count               0
# repeat_customer                              repeat_customer               0
# customer_lifetime_value              customer_lifetime_value               0
# total_order_value                          total_order_value             833
# average_product_price                  average_product_price             732
# average_review_score                    average_review_score             939
# seller_performance_score            seller_performance_score             838
# revenue_per_customer                    revenue_per_customer               0
# order_month                                      order_month               0
# delayed_delivery                            delayed_delivery               0
# review_sentiment                            review_sentiment               0
#
#                                Percentage (%)
# order_id                                 0.00
# customer_id                              0.00
# order_status                             0.00
# order_purchase_timestamp                 0.00
# order_approved_at                        0.15
# order_delivered_carrier_date             1.75
# order_delivered_customer_date            2.87
# order_estimated_delivery_date            0.00
# customer_unique_id                       0.00
# customer_zip_code_prefix                 0.00
# customer_city                            0.00
# customer_state                           0.00
# order_item_id                            0.70
# product_id                               0.70
# seller_id                                0.70
# shipping_limit_date                      0.70
# price                                    0.70
# freight_value                            0.70
# product_category_name                    2.13
# product_name_length                      2.13
# product_description_length               2.13
# product_photos_qty                       2.13
# product_weight_g                         0.72
# product_length_cm                        0.72
# product_height_cm                        0.72
# product_width_cm                         0.72
# payment_sequential                       0.00
# payment_type                             0.00
# payment_installments                     0.00
# payment_value                            0.00
# review_id                                0.84
# review_score                             0.84
# review_comment_title                     0.84
# review_comment_message                   0.86
# review_creation_date                     0.84
# review_answer_timestamp                  0.84
# seller_zip_code_prefix                   0.70
# seller_city                              0.70
# seller_state                             0.70
# product_category_name_english            2.15
# delivery_time                            2.87
# shipping_duration                        1.75
# order_processing_time                    0.15
# customer_purchase_count                  0.00
# repeat_customer                          0.00
# customer_lifetime_value                  0.00
# total_order_value                        0.70
# average_product_price                    0.61
# average_review_score                     0.79
# seller_performance_score                 0.70
# revenue_per_customer                     0.00
# order_month                              0.00
# delayed_delivery                         0.00
# review_sentiment                         0.00

# %% [markdown]
# ## Duplicate Records Removed
#
# Duplicate records were removed during the preprocessing of individual datasets.

# %%
duplicate_report = pd.DataFrame({
    "Dataset":[
        "Customers",
        "Orders",
        "Order Items",
        "Products",
        "Payments",
        "Reviews",
        "Sellers",
        "Geolocation",
        "Category Translation"
    ],

    "Duplicates Removed":[
        0,
        0,
        0,
        0,
        0,
        0,
        0,
        261831,
        0
    ]
})

duplicate_report
# Out:
#                 Dataset  Duplicates Removed
# 0             Customers                   0
# 1                Orders                   0
# 2           Order Items                   0
# 3              Products                   0
# 4              Payments                   0
# 5               Reviews                   0
# 6               Sellers                   0
# 7           Geolocation              261831
# 8  Category Translation                   0

# %% [markdown]
# ## Outliers Detected
#
# Outliers were identified using the Interquartile Range (IQR) method for selected numerical columns.

# %%
outlier_report = pd.DataFrame({
    "Column":[
        "Price",
        "Freight Value",
        "Product Weight",
        "Payment Value"
    ],

    "Outliers Detected":[
        len(price_outliers),
        len(freight_outliers),
        len(outliers_weight),
        len(outliers_payment)
    ]
})

outlier_report
# Out:
#            Column  Outliers Detected
# 0           Price               8427
# 1   Freight Value              12134
# 2  Product Weight               4551
# 3   Payment Value               7981

# %% [markdown]
# ## Outlier Treatment
#
# Outliers were detected for analysis purposes.
#
# To preserve the relationships between datasets, extreme values were retained instead of removing entire rows. This prevents loss of linked order, customer, seller, and product information.

# %%
print("Outlier treatment completed successfully.")
print("No relational records were removed after merging.")
# Out:
# Outlier treatment completed successfully.
# No relational records were removed after merging.

# %% [markdown]
# ## Features Created
#
# New business-oriented features were engineered to support advanced analytics.

# %%
features = pd.DataFrame({
    "Feature Created":[
        "delivery_time",
        "shipping_duration",
        "order_processing_time",
        "customer_purchase_count",
        "repeat_customer",
        "customer_lifetime_value",
        "total_order_value",
        "average_product_price",
        "average_review_score",
        "seller_performance_score",
        "revenue_per_customer",
        "order_month"
    ]
})

features
# Out:
#              Feature Created
# 0              delivery_time
# 1          shipping_duration
# 2      order_processing_time
# 3    customer_purchase_count
# 4            repeat_customer
# 5    customer_lifetime_value
# 6          total_order_value
# 7      average_product_price
# 8       average_review_score
# 9   seller_performance_score
# 10      revenue_per_customer
# 11               order_month

# %% [markdown]
# ## Tables Merged
#
# The following cleaned datasets were merged to create the final analytical dataset.

# %%
tables = pd.DataFrame({
    "Merged Tables":[
        "customers",
        "orders",
        "order_items",
        "products",
        "payments",
        "reviews",
        "sellers",
        "category_translation"
    ]
})

tables
# Out:
#           Merged Tables
# 0             customers
# 1                orders
# 2           order_items
# 3              products
# 4              payments
# 5               reviews
# 6               sellers
# 7  category_translation

# %% [markdown]
# ## Final Dataset Dimensions
#
# The final feature-engineered dataset contains the following dimensions.

# %%
print("Rows    :", merged_df.shape[0])
print("Columns :", merged_df.shape[1])
# Out:
# Rows    : 119143
# Columns : 54

# %% [markdown]
# ## Export Feature Engineered Dataset
#
# The final dataset is exported as a CSV file for dashboard development.

# %%
merged_df.to_csv(
    "../cleaned/feature_engineered_dataset.csv",
    index=False
)

print("Feature Engineered Dataset Exported Successfully!")
# Out:
# Feature Engineered Dataset Exported Successfully!

# %% [markdown]
# ## Export Data Quality Report
#
# A summary report is exported as a CSV file.

# %%
report = pd.DataFrame({
    "Metric":[
        "Final Rows",
        "Final Columns",
        "Total Features Created"
    ],

    "Value":[
        merged_df.shape[0],
        merged_df.shape[1],
        len(features)
    ]
})

report.to_csv(
    "../cleaned/data_quality_report.csv",
    index=False
)

print("Data Quality Report Exported Successfully!")
# Out:
# Data Quality Report Exported Successfully!

# %% [markdown]
# # Phase 5 Summary
#
# The data quality process has been successfully completed.
#
# ✔ Processed all datasets
#
# ✔ Cleaned missing values
#
# ✔ Removed duplicate records
#
# ✔ Detected and analyzed outliers
#
# ✔ Performed feature engineering
#
# ✔ Merged datasets
#
# ✔ Generated business insights
#
# ✔ Exported feature-engineered dataset
#
# ✔ Generated data quality report
#
# The cleaned dataset is now ready for visualization and deployment in the Flask Analytics Dashboard.

# %%
orders["order_status"].value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
merged_df["order_status"].value_counts()
# Out:
# order_status
# delivered      115723
# shipped          1256
# canceled          750
# unavailable       652
# invoiced          378
# processing        376
# created             5
# approved            3
# Name: count, dtype: int64
